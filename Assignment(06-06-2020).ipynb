# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv("https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/german_credit_data.csv",index_col=0)
df1
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male    2     own             NaN           little           1169
# 1     22  female    2     own          little         moderate           5951
# 2     49    male    1     own          little              NaN           2096
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
# ...

# %%
#1

df1.dropna(axis=1)
# Out:
#      Age     Sex  Job Housing  Credit amount  Duration              Purpose
# 0     67    male    2     own           1169         6             radio/TV
# 1     22  female    2     own           5951        48             radio/TV
# 2     49    male    1     own           2096        12            education
# 3     45    male    2    free           7882        42  furniture/equipment
# 4     53    male    2    free           4870        24                  car
# ..   ...     ...  ...     ...            ...       ...                  ...
# 995   31  female    1     own           1736        12  furniture/equipment
# 996   40    male    3     own           3857        30                  car
# 997   38    male    2     own            804        12             radio/TV
# 998   23    male    2    free           1845        45             radio/TV
# 999   27    male    2     own           4576        45                  car
#
# [1000 rows x 7 columns]

# %%
#2

print("Top seven")
df1.head(7)
# Out:
# Top seven
# Below Five
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
#      Duration              Purpose
# 995        12  furniture/equipment
# 996        30                  car
# 997        12             radio/TV
# 998        45             radio/TV
# 999        45                  car

# %%
print("Below Five")
df1.tail(5)
# Out:
# Below Five
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
#      Duration              Purpose
# 995        12  furniture/equipment
# 996        30                  car
# 997        12             radio/TV
# 998        45             radio/TV
# 999        45                  car

# %%
#3

print("No. of entries in data_frame is:",df1.shape[0])
# Out:
# No. of entries in data_frame is: 1000

# %%
#4

print("Columns in dataframe:")
print(list(df1.columns))
print("No. of columns:",len(list(df1)))
# Out:
# Columns in dataframe:
# ['Age', 'Sex', 'Job', 'Housing', 'Saving accounts', 'Checking account', 'Credit amount', 'Duration', 'Purpose']
# No. of columns: 9

# %%
#5

print("row indices are:")
for i in df1.index:
    print(i,end=",")
# Out:
# row indices are:
# ...

# %%
#6

df1.dtypes
# Out:
# Age                  int64
# Sex                 object
# Job                  int64
# Housing             object
# Saving accounts     object
# Checking account    object
# Credit amount        int64
# Duration             int64
# Purpose             object
# dtype: object

# %%
#7

df1.describe()
# Out:
#                Age          Job  Credit amount     Duration
# count  1000.000000  1000.000000    1000.000000  1000.000000
# mean     35.546000     1.904000    3271.258000    20.903000
# std      11.375469     0.653614    2822.736876    12.058814
# min      19.000000     0.000000     250.000000     4.000000
# 25%      27.000000     2.000000    1365.500000    12.000000
# 50%      33.000000     2.000000    2319.500000    18.000000
# 75%      42.000000     2.000000    3972.250000    24.000000
# max      75.000000     3.000000   18424.000000    72.000000

# %%
#8

df1.describe(include=['O'])
# Out:
#          Sex Housing Saving accounts Checking account Purpose
# count   1000    1000             817              606    1000
# unique     2       3               4                3       8
# top     male     own          little           little     car
# freq     690     713             603              274     337

# %%
#9

df1.isna().sum()
# Out:
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# dtype: int64

# %%
#10

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   object
#  4   Saving accounts   817 non-null    object
#  5   Checking account  606 non-null    object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 78.1+ KB

# %%
#11
print("Using iloc")
print(df1.iloc[10:20,1:4])
print("Using loc")
print(df1.loc[9:11,'Job':'Purpose'])
# Out:
# Using iloc
#        Sex  Job Housing
# 10  female    2    rent
# 11  female    2    rent
# 12  female    2     own
# 13    male    1     own
# 14  female    2    rent
# 15  female    1     own
# 16    male    2     own
# 17    male    2     own
# 18  female    3    free
# 19    male    2     own
# Using loc
#     Job Housing Saving accounts Checking account  Credit amount  Duration  \
# 9     3     own          little         moderate           5234        30
# 10    2    rent          little         moderate           1295        12
# 11    2    rent          little           little           4308        48
#
#      Purpose
# 9        car
# 10       car
# 11  business

# %%
#12

for unq in df1.columns:
    print(df1[unq].unique())
# Out:
# [67 22 49 45 53 35 61 28 25 24 60 32 44 31 48 26 36 39 42 34 63 27 30 57
#  33 37 58 23 29 52 50 46 51 41 40 66 47 56 54 20 21 38 70 65 74 68 43 55
#  64 75 19 62 59]
# ['male' 'female']
# [2 1 3 0]
# ['own' 'free' 'rent']
# [nan 'little' 'quite rich' 'rich' 'moderate']
# ['little' 'moderate' nan 'rich']
# [ 1169  5951  2096  7882  4870  9055  2835  6948  3059  5234  1295  4308
#   1567  1199  1403  1282  2424  8072 12579  3430  2134  2647  2241  1804
#   2069  1374   426   409  2415  6836  1913  4020  5866  1264  1474  4746
#   6110  2100  1225   458  2333  1158  6204  6187  6143  1393  2299  1352
#   7228  2073  5965  1262  3378  2225   783  6468  9566  1961  6229  1391
#   1537  1953 14421  3181  5190  2171  1007  1819  2394  8133   730  1164
#   5954  1977  1526  3965  4771  9436  3832  5943  1213  1568  1755  2315
#   1412 12612  2249  1108   618  1409   797  3617  1318 15945  2012  2622
#   2337  7057  1469  2323   932  1919  2445 11938  6458  6078  7721  1410
# ...
