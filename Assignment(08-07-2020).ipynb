# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=plt.imread("objects.jpg")
print(img.shape)
# Out:
# (443, 406, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,2])

# %%
plt.imshow(img[:,:,0],cmap='gray')

# %%
plt.imshow(img[:,0:150])

# %%
plt.imshow(img[:500,:300])

# %%
plt.imshow(img[:,150:250])
